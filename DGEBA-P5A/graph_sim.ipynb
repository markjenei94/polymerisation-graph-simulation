# %%
from modules.graph_simulation import KineticRates, System, GraphSimulation
from modules.post_process import PostProcess
import matplotlib.pyplot as plt
import numpy as np

# %%
loads = [75, 30]
functionalities = [2, 5]
kinetic_rates = KineticRates(functionalities, preset="two_component_uniform")
output_folder = "/home/markjenei/polymerisation-graph-simulation/DGEBA-P5A/run_30/"
target_conversion = 0.8 # max. extent of reaction
for i in range(50):
    system = System(loads, kinetic_rates)
    sim = GraphSimulation(system, 'data', cycles_allowed=True)
    fsse_path = "./p5a_fsse.data"
    conv_path = "./p5a_conv.data"
    fsse_monomer_index = 1 # FSSE on monomer B := 1, see above
    sim.set_fsse_file_paths(fsse_monomer_index, fsse_path, conv_path)
    index = str(i).zfill(max(2, len(str(i))))
    save_file_loc = output_folder + "run_"+str(index)+".out"
    sim.run(target_conversion, save_file_loc)

pp = PostProcess(loads, 'file', reactions_folder_path=output_folder, reaction_file_root='run_')
pp.average_sizes(reduced=True)
rpdi = pp.topology_data["dispersion_index"]
c = np.linspace(0, target_conversion, len(rpdi))
gel_point = c[np.nonzero(rpdi == max(rpdi))[0][0]]
print(f"gel point {gel_point}")

fig, ax = plt.subplots(1, 1, figsize=(6,4))
ax.axvline(gel_point, ls='--', color="xkcd:silver", label="gel point")
ax.plot(c, rpdi)
ax.set_xlabel("conversion")
ax.set_title("reduced poly-dispersity index")
ax.set_ylabel("rPDI")
ax.legend(frameon=False)
for side in ["top", "bottom", "left", "right"]:
    ax.spines[side].set_visible(False)
f = open("./gel_points", 'a')
f.write(f"{loads[0]} {loads[1]}\t{gel_point}\n")
f.close()
plt.savefig("./dgeba_p5a_30.png", bbox_inches="tight")
# Out:
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..................................................
# gel point 0.6050420168067228

# %%
loads = [150, 60]
functionalities = [2, 5]
kinetic_rates = KineticRates(functionalities, preset="two_component_uniform")
output_folder = "/home/markjenei/polymerisation-graph-simulation/DGEBA-P5A/run_60/"
target_conversion = 0.8 # max. extent of reaction
for i in range(30):
    system = System(loads, kinetic_rates)
    sim = GraphSimulation(system, 'data', cycles_allowed=True)
    fsse_path = "./p5a_fsse.data"
    conv_path = "./p5a_conv.data"
    fsse_monomer_index = 1 # FSSE on monomer B := 1, see above
    sim.set_fsse_file_paths(fsse_monomer_index, fsse_path, conv_path)
    index = str(i).zfill(max(2, len(str(i))))
    save_file_loc = output_folder + "run_"+str(index)+".out"
    sim.run(target_conversion, save_file_loc)

pp = PostProcess(loads, 'file', reactions_folder_path=output_folder, reaction_file_root='run_')
pp.average_sizes(reduced=True)
rpdi = pp.topology_data["dispersion_index"]
c = np.linspace(0, target_conversion, len(rpdi))
gel_point = c[np.nonzero(rpdi == max(rpdi))[0][0]]
print(f"gel point {gel_point}")

fig, ax = plt.subplots(1, 1, figsize=(6,4))
ax.axvline(gel_point, ls='--', color="xkcd:silver", label="gel point")
ax.plot(c, rpdi)
ax.set_xlabel("conversion")
ax.set_title("reduced poly-dispersity index")
ax.set_ylabel("rPDI")
ax.legend(frameon=False)
for side in ["top", "bottom", "left", "right"]:
    ax.spines[side].set_visible(False)
f = open("./gel_points", 'a')
f.write(f"{loads[0]} {loads[1]}\t{gel_point}\n")
f.close()
plt.savefig("./dgeba_p5a_60.png", bbox_inches="tight")
# Out:
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..............................
# gel point 0.6225941422594142

# %%
loads = [250, 100]
functionalities = [2, 5]
kinetic_rates = KineticRates(functionalities, preset="two_component_uniform")
output_folder = "/home/markjenei/polymerisation-graph-simulation/DGEBA-P5A/run_100/"
target_conversion = 0.8 # max. extent of reaction
for i in range(10):
    system = System(loads, kinetic_rates)
    sim = GraphSimulation(system, 'data', cycles_allowed=True)
    fsse_path = "./p5a_fsse.data"
    conv_path = "./p5a_conv.data"
    fsse_monomer_index = 1 # FSSE on monomer B := 1, see above
    sim.set_fsse_file_paths(fsse_monomer_index, fsse_path, conv_path)
    index = str(i).zfill(max(2, len(str(i))))
    save_file_loc = output_folder + "run_"+str(index)+".out"
    sim.run(target_conversion, save_file_loc)

pp = PostProcess(loads, 'file', reactions_folder_path=output_folder, reaction_file_root='run_')
pp.average_sizes(reduced=True)
rpdi = pp.topology_data["dispersion_index"]
c = np.linspace(0, target_conversion, len(rpdi))
gel_point = c[np.nonzero(rpdi == max(rpdi))[0][0]]
print(f"gel point {gel_point}")

fig, ax = plt.subplots(1, 1, figsize=(6,4))
ax.axvline(gel_point, ls='--', color="xkcd:silver", label="gel point")
ax.plot(c, rpdi)
ax.set_xlabel("conversion")
ax.set_title("reduced poly-dispersity index")
ax.set_ylabel("rPDI")
ax.legend(frameon=False)
for side in ["top", "bottom", "left", "right"]:
    ax.spines[side].set_visible(False)
f = open("./gel_points", 'a')
f.write(f"{loads[0]} {loads[1]}\t{gel_point}\n")
f.close()
plt.savefig("./dgeba_p5a_100.png", bbox_inches="tight")
# Out:
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# ..........
# gel point 0.6135338345864662

# %%
from tqdm import tqdm
from modules.graph_simulation import KineticRates, System, GraphSimulation
from modules.post_process import PostProcess
import matplotlib.pyplot as plt
import numpy as np

loads = [750, 300]
functionalities = [2, 5]
kinetic_rates = KineticRates(functionalities, preset="two_component_uniform")
output_folder = "/home/markjenei/polymerisation-graph-simulation/DGEBA-P5A/run_300d/"
target_conversion = 0.8 # max. extent of reaction
for i in range(4):
    system = System(loads, kinetic_rates)
    sim = GraphSimulation(system, 'data', cycles_allowed=True)
    fsse_path = "./p5a_fsse.data"
    conv_path = "./p5a_conv.data"
    fsse_monomer_index = 1 # FSSE on monomer B := 1, see above
    sim.set_fsse_file_paths(fsse_monomer_index, fsse_path, conv_path)
    index = str(i).zfill(max(2, len(str(i))))
    save_file_loc = output_folder + "run_"+str(index)+".out"
    sim.run(target_conversion, save_file_loc)

pp = PostProcess(loads, 'file', reactions_folder_path=output_folder, reaction_file_root='run_')
pp.average_sizes(reduced=True)
rpdi = pp.topology_data["dispersion_index"]
c = np.linspace(0, target_conversion, len(rpdi))
gel_point = c[np.nonzero(rpdi == max(rpdi))[0][0]]
print(f"gel point {gel_point}")

fig, ax = plt.subplots(1, 1, figsize=(6,4))
ax.axvline(gel_point, ls='--', color="xkcd:silver", label="gel point")
ax.plot(c, rpdi)
ax.set_xlabel("conversion")
ax.set_title("reduced poly-dispersity index")
ax.set_ylabel("rPDI")
ax.legend(frameon=False)
for side in ["top", "bottom", "left", "right"]:
    ax.spines[side].set_visible(False)
f = open("./gel_points", 'a')
f.write(f"{loads[0]} {loads[1]}\t{gel_point}\n")
f.close()
plt.savefig("./dgeba_p5a_300.png", bbox_inches="tight")
# Out:
# 100%|██████████| 1200/1200.0 [07:16<00:00,  2.75it/s]
# 100%|██████████| 1200/1200.0 [07:00<00:00,  2.85it/s]
# 100%|██████████| 1200/1200.0 [07:12<00:00,  2.77it/s]
# 100%|██████████| 1200/1200.0 [07:26<00:00,  2.69it/s]
# ....
# gel point 0.5577981651376147

# %%
loads = [140, 56]
functionalities = [2, 5]
kinetic_rates = KineticRates(functionalities, preset="two_component_uniform")
output_folder = "/home/markjenei/polymerisation-graph-simulation/DGEBA-P5A/run_56/"
target_conversion = 0.8 # max. extent of reaction
for i in range(50):
    system = System(loads, kinetic_rates)
    sim = GraphSimulation(system, 'data', cycles_allowed=True)
    fsse_path = "/home/markjenei/polymerisation-graph-simulation/DGEBA-P5A/p5a_fsse.data"
    conv_path = "/home/markjenei/polymerisation-graph-simulation/DGEBA-P5A/p5a_conv.data"
    fsse_monomer_index = 1 # FSSE on monomer B := 1, see above
    sim.set_fsse_file_paths(fsse_monomer_index, fsse_path, conv_path)
    index = str(i).zfill(max(2, len(str(i))))
    save_file_loc = output_folder + "run_"+str(index)+".out"
    sim.run(target_conversion, save_file_loc)

pp = PostProcess(loads, 'file', reactions_folder_path=output_folder, reaction_file_root='run_')
pp.average_sizes(reduced=False)
rpdi = pp.topology_data["dispersion_index"]
c = np.linspace(0, target_conversion, len(rpdi))
gel_point = c[np.nonzero(rpdi == max(rpdi))[0][0]]
print(f"gel point {gel_point}")

fig, ax = plt.subplots(1, 1, figsize=(6,4))
ax.axvline(gel_point, ls='--', color="xkcd:silver", label="gel point")
ax.plot(c, rpdi)
ax.set_xlabel("conversion")
ax.set_title("reduced poly-dispersity index")
ax.set_ylabel("rPDI")
ax.legend(frameon=False)
for side in ["top", "bottom", "left", "right"]:
    ax.spines[side].set_visible(False)
f = open("./gel_points", 'a')
f.write(f"{loads[0]} {loads[1]}\t{gel_point}\n")
f.close()
plt.savefig("./dgeba_p5a_56.png", bbox_inches="tight")
# Out:
# 100%|██████████| 224/224.0 [00:03<00:00, 71.75it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 74.55it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 71.16it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 68.87it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 74.49it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 73.80it/s]
# 100%|██████████| 224/224.0 [00:02<00:00, 76.26it/s]
# 100%|██████████| 224/224.0 [00:02<00:00, 75.57it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 71.52it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 70.28it/s]
# 100%|██████████| 224/224.0 [00:02<00:00, 75.67it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 72.93it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 72.27it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 69.05it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 72.36it/s]
# 100%|██████████| 224/224.0 [00:02<00:00, 75.54it/s]
# 100%|██████████| 224/224.0 [00:02<00:00, 76.56it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 71.26it/s]
# 100%|██████████| 224/224.0 [00:02<00:00, 75.85it/s]
# 100%|██████████| 224/224.0 [00:02<00:00, 76.75it/s]
# 100%|██████████| 224/224.0 [00:02<00:00, 76.48it/s]
# 100%|██████████| 224/224.0 [00:02<00:00, 75.25it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 71.76it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 72.09it/s]
# 100%|██████████| 224/224.0 [00:02<00:00, 76.27it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 73.26it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 72.29it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 71.31it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 70.73it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 72.45it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 73.35it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 72.36it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 73.32it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 73.04it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 73.44it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 73.23it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 71.75it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 73.74it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 68.04it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 70.10it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 71.92it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 71.45it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 68.28it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 67.01it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 72.11it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 70.42it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 70.16it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 70.31it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 72.21it/s]
# 100%|██████████| 224/224.0 [00:03<00:00, 72.35it/s]
# ..................................................
# gel point 0.6565022421524663

# %% [markdown]
# ### Ideal simulations

# %%
from modules.graph_simulation import KineticRates, System, GraphSimulation
from modules.post_process import PostProcess
import matplotlib.pyplot as plt
import numpy as np


loads = [750, 300]
functionalities = [2, 5]
kinetic_rates = KineticRates(functionalities, preset="two_component_uniform")
output_folder = "/home/markjenei/polymerisation-graph-simulation/DGEBA-P5A/run_i300b/"
target_conversion = 0.8 # max. extent of reaction
for i in range(10):
    system = System(loads, kinetic_rates)
    sim = GraphSimulation(system, 'ideal', cycles_allowed=True)
    fsse_monomer_index = 1 # FSSE on monomer B := 1, see above
    index = str(i).zfill(max(2, len(str(i))))
    save_file_loc = output_folder + "run_"+str(index)+".out"
    sim.run(target_conversion, save_file_loc)
# Out:
# 100%|██████████| 1200/1200.0 [07:35<00:00,  2.63it/s]
# 100%|██████████| 1200/1200.0 [07:15<00:00,  2.76it/s]
# 100%|██████████| 1200/1200.0 [07:13<00:00,  2.77it/s]
# 100%|██████████| 1200/1200.0 [07:18<00:00,  2.74it/s]
# 100%|██████████| 1200/1200.0 [07:13<00:00,  2.77it/s]
# 100%|██████████| 1200/1200.0 [07:12<00:00,  2.78it/s]
# 100%|██████████| 1200/1200.0 [07:13<00:00,  2.77it/s]
# 100%|██████████| 1200/1200.0 [07:10<00:00,  2.79it/s]
# 100%|██████████| 1200/1200.0 [07:17<00:00,  2.74it/s]
# 100%|██████████| 1200/1200.0 [07:09<00:00,  2.80it/s]

# %%
output_folder = "/home/markjenei/polymerisation-graph-simulation/DGEBA-P5A/run_56/"
pp = PostProcess(loads, 'file', reactions_folder_path=output_folder, reaction_file_root='run_')
pp.average_sizes(reduced=False)
rpdi = pp.topology_data["dispersion_index"]
mn = pp.topology_data["number_average_size"]
mw = pp.topology_data["weight_average_size"]
c = np.linspace(0, target_conversion, len(rpdi))
gel_point = c[np.nonzero(rpdi == max(rpdi))[0][0]]
print(f"gel point {gel_point}")

output_folder = "/home/markjenei/polymerisation-graph-simulation/DGEBA-P5A/run_56i/"
pp = PostProcess(loads, 'file', reactions_folder_path=output_folder, reaction_file_root='run_')
pp.average_sizes(reduced=False)
irpdi = pp.topology_data["dispersion_index"]
imn = pp.topology_data["number_average_size"]
imw = pp.topology_data["weight_average_size"]
ic = np.linspace(0, target_conversion, len(irpdi))
igel_point = ic[np.nonzero(irpdi == max(irpdi))[0][0]]
print(f"gel point {igel_point}")

plt.plot(ic, irpdi)
plt.plot(c, rpdi)
# Out:
# ..................................................
# gel point 0.6565022421524663
# ....................................................................................................
# gel point 0.6385650224215247

# %%
from modules.graph_simulation import KineticRates, System, GraphSimulation
from modules.post_process import PostProcess
import matplotlib.pyplot as plt
import numpy as np

loads = [250, 100]
functionalities = [2, 5]
kinetic_rates = KineticRates(functionalities, preset="two_component_uniform")
target_conversion = 0.8 # max. extent of reaction
output_folder = "/home/markjenei/polymerisation-graph-simulation/DGEBA-P5A/constant_100/"
for i in range(10):
    system = System(loads, kinetic_rates)
    fsse1 = [1., 1., 0.]
    fsse2 = [5., 3.2, 2., 1.5, 1., 0.]
    sim = GraphSimulation(system, [fsse1, fsse2], cycles_allowed=True)
    index = str(i).zfill(max(2, len(str(i))))
    save_file_loc = output_folder + "run_"+str(index)+".out"
    sim.run(target_conversion, save_file_loc)
# Out:
# 100%|██████████| 400/400.0 [00:17<00:00, 23.26it/s]
# 100%|██████████| 400/400.0 [00:16<00:00, 23.72it/s]
# 100%|██████████| 400/400.0 [00:16<00:00, 23.79it/s]
# 100%|██████████| 400/400.0 [00:17<00:00, 23.14it/s]
# 100%|██████████| 400/400.0 [00:16<00:00, 23.73it/s]
# 100%|██████████| 400/400.0 [00:16<00:00, 23.57it/s]
# 100%|██████████| 400/400.0 [00:16<00:00, 23.62it/s]
# 100%|██████████| 400/400.0 [00:16<00:00, 23.54it/s]
# 100%|██████████| 400/400.0 [00:19<00:00, 20.03it/s]
# 100%|██████████| 400/400.0 [00:25<00:00, 15.40it/s]

# %%
from modules.graph_simulation import KineticRates, System, GraphSimulation
from modules.post_process import PostProcess
import matplotlib.pyplot as plt
import numpy as np

loads = [750, 300]
functionalities = [2, 5]
kinetic_rates = KineticRates(functionalities, preset="two_component_uniform")
target_conversion = 0.8 # max. extent of reaction

output_folder = "/home/markjenei/polymerisation-graph-simulation/DGEBA-P5A/run_i300b/"
pp = PostProcess(loads, 'file', reactions_folder_path=output_folder, reaction_file_root='run_')
pp.average_sizes(reduced=False)
irpdi = pp.topology_data["dispersion_index"]
imn = pp.topology_data["number_average_size"]
imw = pp.topology_data["weight_average_size"]
ic = np.linspace(0, target_conversion, len(irpdi))
igel_point = ic[np.nonzero(irpdi == max(irpdi))[0][0]]
print(f"gel point {igel_point}")

output_folder = "/home/markjenei/polymerisation-graph-simulation/DGEBA-P5A/run_300/"
pp = PostProcess(loads, 'file', reactions_folder_path=output_folder, reaction_file_root='run_')
pp.average_sizes(reduced=False)
rpdi = pp.topology_data["dispersion_index"]
mn = pp.topology_data["number_average_size"]
mw = pp.topology_data["weight_average_size"]
c = np.linspace(0, target_conversion, len(rpdi))
gel_point = c[np.nonzero(rpdi == max(rpdi))[0][0]]
print(f"gel point {gel_point}")

output_folder = "/home/markjenei/polymerisation-graph-simulation/DGEBA-P5A/constant_300/"
pp = PostProcess(loads, 'file', reactions_folder_path=output_folder, reaction_file_root='run_')
pp.average_sizes(reduced=False)
lrpdi = pp.topology_data["dispersion_index"]
lmn = pp.topology_data["number_average_size"]
lmw = pp.topology_data["weight_average_size"]
lc = np.linspace(0, target_conversion, len(lrpdi))
lgel_point = lc[np.nonzero(lrpdi == max(lrpdi))[0][0]]
print(f"gel point {lgel_point}")#
# Out:
# ..........
# gel point 0.6185154295246038
# ............
# gel point 0.6291909924937448
# ..........
# gel point 0.6365304420350292

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,4))
#ax.axvline(igel_point, ls='--', color="xkcd:silver", label="gel point")
#ax.axvline(gel_point, ls='--', color="xkcd:silver", label="gel point")
ax.plot(ic, irpdi, label='ideal')
ax.plot(c, rpdi, label='fsse')
#ax.plot(lc, lrpdi, label='linear', ls='--')
ax.set_xlabel("conversion")
ax.set_title("reduced poly-dispersity index")
ax.set_ylabel("rPDI")
ax.legend(frameon=False)
for side in ["top", "bottom", "left", "right"]:
    ax.spines[side].set_visible(False)
f = open("./gel_points", 'a')
f.write(f"i {loads[0]} {loads[1]}\t{gel_point}\n")
f.close()
plt.savefig("/home/markjenei/polymerisation-graph-simulation/DGEBA-P5A/dgeba_p5a_rpdi.png", bbox_inches="tight")

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,4))
ax.plot(ic, imn, label='ideal')
ax.plot(c, mn, label='fsse')
#ax.plot(lc, lmn, label='linear', ls='--')
ax.set_xlabel("conversion")
ax.set_title("number average mol. size")
ax.set_ylabel(r"M$_n$")
ax.legend(frameon=False)
for side in ["top", "bottom", "left", "right"]:
    ax.spines[side].set_visible(False)
plt.savefig("/home/markjenei/polymerisation-graph-simulation/DGEBA-P5A/dgeba_p5a_mn.png", bbox_inches="tight")

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,4))
ax.plot(ic, imw, label='ideal')
ax.plot(c, mw, label='fsse')
#ax.plot(lc, lmw, label='linear', ls='--')
ax.set_xlabel("conversion")
ax.set_title("weight average mol. size")
ax.set_ylabel(r"M$_w$")
ax.legend(frameon=False)
for side in ["top", "bottom", "left", "right"]:
    ax.spines[side].set_visible(False)
plt.savefig("/home/markjenei/polymerisation-graph-simulation/DGEBA-P5A/dgeba_p5a_mw.png", bbox_inches="tight")
